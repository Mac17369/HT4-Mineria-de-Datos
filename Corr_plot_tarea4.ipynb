# %%
import pandas as pd 
from sklearn.manifold import TSNE,Isomap,LocallyLinearEmbedding
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos = pd.read_csv("C:/Users/LENOVO/Desktop/Clases/Minería de datos/Github/HT4-Mineria-de-Datos/cuantitativas_precios.csv", header = "infer")

# %%
datos.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MSSubClass', 'LotFrontage', 'LotArea',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'X1stFlrSF',
#        'X2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'X3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
datos.iloc[:,2:31].columns
#datos.drop(['MSSubClass','OverallQual','OverallCond','YearBuilt', 'YearRemodAdd', 'LowQualFinSF','KitchenAbvGr'], axis = 1)
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'X1stFlrSF', 'X2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF'],
#       dtype='object')

# %%
x = datos.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(datos)
df = pd.DataFrame(x_scaled, columns = datos.columns)
#df.rename(columns = datos.columns)

# %% [markdown]
# ## Correlaciones con distintos métodos

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# ...

# %%
corr = df.corr(method = 'spearman')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# ...

# %%
corr = df.corr(method = 'kendall')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cf717fd5ac32> in <module>
# ----> 1 corr = df.corr(method = 'kendall')
#       2 corr.style.background_gradient(cmap='coolwarm').set_precision(2)
#
# NameError: name 'df' is not defined

# %%
corr = df.corr(method = 'pearson')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-435db244d812> in <module>
# ----> 1 corr = df.corr(method = 'pearson')
#       2 corr.style.background_gradient(cmap='coolwarm').set_precision(2)
#
# NameError: name 'df' is not defined

# %%
type(corr)
# Out:
# pandas.core.frame.DataFrame
